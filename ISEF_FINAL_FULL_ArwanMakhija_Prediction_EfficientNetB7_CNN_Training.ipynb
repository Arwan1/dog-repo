# %% [markdown]
# <a href="https://colab.research.google.com/github/radhakrishnan-omotec/arwan-iris-dog-repo/blob/main/ISEF_FINAL_FULL_ArwanMakhija_Prediction_EfficientNetB7_CNN_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---

# %% [markdown]
# # Enhanced Python Notebook for **TailSense** : EfficientNetB7-based Canine Pet Image and Audio Spectrogram Classification
#
# ### Author : ARWAN MAKHIJA

# %% [markdown]
# Below is an enhanced Python notebook implementation for Google Colab that integrates both image classification and spectrogram audio classification using the EfficientNetB7 model, optimized for maximum accuracy and depth.
#
# It leverages EfficientNetB7’s deep architecture (~60M parameters) with residual connections for classifying dog emotions from both image and audio data derived from videos of a Cocker Spaniel.
#
# The dataset is assumed to contain 8-10 emotion classes (e.g., "defensive," "stressed," "friendly"), and the implementation includes data preprocessing, model training, evaluation, a Gradio interface for real-time inference, and TensorFlow Lite conversion for edge deployment.

# %% [markdown]
# # EfficientNetB7-based Image Classification

# %% [markdown]
# # **Part 1** : Cocker Spaniel 8 Emotions Prediction EfficientNetB7 CNN Model Traning

# %% [markdown]
# ---

# %% [markdown]
# # My Project Key Enhancements:
# **8-Class Cocker Spaniel Emotion Classifier:**<br>
# Replaced the 3-class tongue classification (Healthy Tongue, Tongue with Moderate Coating, Tongue with Severe Coating) with an 8-class emotion classification (Sad, Happy, Stress, Restless, Normal, Love, Unhappy, Tired).
# Updated dataset paths to a hypothetical Cocker Spaniel emotion dataset, with class folders named after emotions.<br><br>
# Modified class labels, image counting, and visualization to handle 8 classes, ensuring compatibility with the new dataset structure.<br><br>
# Adjusted the confusion matrix and classification report to reflect the increased number of classes, with a larger figure size for clarity.<br><br><br>
#
# **EfficientNetB7-Based Transfer-Learning Model:**<br>
# Replaced the Sequential CNN with a pre-trained EfficientNetB7 model from tensorflow.keras.applications, using ImageNet weights for transfer learning.
# Froze the base model layers (base_model.trainable = False) to leverage pre-trained features and reduce training time.<br><br>
# Added custom layers: GlobalAveragePooling2D for spatial dimension reduction, two dense layers (512 and 256 units) with ReLU activation, and dropout layers (0.5 and 0.3) to prevent overfitting. The final dense layer outputs probabilities for 8 classes with softmax activation.<br><br>
# Updated the Grad-CAM function to use the last convolutional layer of EfficientNetB7 (conv5_block3_3_conv), ensuring compatibility with the new model architecture.<br>

# %% [markdown]
# ---

# %% [markdown]
# **ISEF Reviewer Notes:**<br>
# The code assumes the existence of a Cocker Spaniel emotion dataset at Cocker_Spaniel_Emotions_Dataset.zip, with subfolders named after each emotion (Sad, Happy, etc.). Users must provide this dataset and update paths accordingly.<br><br>
# The Grad-CAM implementation uses thetop_conv layer, which is the last convolutional layer in EfficientNetB7. Users should verify this using model.summary() if the architecture differs.<br><br>
# The notebook is designed for Google Colab with GPU acceleration, as specified in the original metadata.<br><br>
# The code supports .jpg and .png formats, accommodating common image types in emotion datasets.<br><br>
# Training epochs are set to 50, with EarlyStopping to prevent overfitting; users may adjust based on dataset size and convergence behavior.<br>

# %% [markdown]
# ---
# ---

# %% [markdown]
# #Cocker_Spaniel_Emotion_EfficientNetB7
#
# ### Enhanced for 8-class Cocker Spaniel emotion prediction using EfficientNetB7 with transfer learning.

# %% [markdown]
# # 1) Import necessary libraries

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Collecting google-pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Collecting tensorboard~=2.19.0 (from tensorflow)
#   Downloading tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.5.1)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow)
#   Downloading tensorflow_io_gcs_filesystem-0.37.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow)
#   Downloading wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/lib/python3/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.3.6)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.19.0->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard~=2.19.0->tensorflow)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Downloading tensorflow-2.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (644.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.9/644.9 MB 808.1 kB/s eta 0:00:00
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 6.5 MB/s eta 0:00:00
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 97.7 MB/s eta 0:00:00
# Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 144.7 MB/s eta 0:00:00
# Downloading tensorflow_io_gcs_filesystem-0.37.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 135.9 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 144.0 MB/s eta 0:00:00
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 23.5 MB/s eta 0:00:00
# Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 7.8 MB/s eta 0:00:00
# Installing collected packages: libclang, flatbuffers, wheel, werkzeug, tensorflow-io-gcs-filesystem, tensorboard-data-server, google-pasta, tensorboard, astunparse, tensorflow
# Successfully installed astunparse-1.6.3 flatbuffers-25.2.10 google-pasta-0.2.0 libclang-18.1.1 tensorboard-2.19.0 tensorboard-data-server-0.7.2 tensorflow-2.19.0 tensorflow-io-gcs-filesystem-0.37.1 werkzeug-3.1.3 wheel-0.45.1

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.19.0

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (2.0.2)
# Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (63.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 22.4 MB/s eta 0:00:00
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.11.0.86

# %%
# Import necessary libraries
from google.colab import drive
import tensorflow as tf
import os
import shutil
import random
import pathlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB7
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.preprocessing import image
import cv2
import PIL

# %% [markdown]
# # 1) Mount Google Drive

# %%
# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 1) Check TensorFlow version

# %%
# Check TensorFlow version
print(f"TensorFlow Version: {tf.__version__}")
# Out:
# TensorFlow Version: 2.19.0

# %% [markdown]
# # 1) Unzip the dataset (assumed to be a Cocker Spaniel emotion dataset)

# %%
# Unzip the dataset (assumed to be a Cocker Spaniel emotion dataset)
# !unzip "/content/drive/MyDrive/1.ALL-RESEARCH/IRIS-ARWAN/ISEF_DATASET/IMAGE_DATASET/Input_Image_Dataset.zip" -d "/content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_OZCG8G0EETYP.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_OZX7IOA2FME8.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_P0D80C6XQ9ZO.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_P13IJTBCKYPM.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_P1AG411WCA65.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_P237BOPNIOWR.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_P37FZSPELUUY.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_P4E61ILAQNMB.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_P5W32MFNCODH.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_P75NR9GRJBAQ.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_P8CWV6WYKGL2.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_P8ELR0YTA0LO.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_P8UI710Q626D.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_P9DKFEKIXL81.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_PAD162QUD4TK.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_PB3O8CMTWIZJ.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_PB3O8CMTWIZJ_aug.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_PCH73RB5FD85.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_PDQ6PFUGX1G0.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_PFCWIOLYUQDD.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_PHQ6Y4V1HB1L.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_PHRSWVO7ECOH.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_PHXPHOL2XXNU.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_PI4Z4YCXUAS3.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_PJRJL90JCZPG.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_PK3M0LNILUI4.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_PL5SO9LNVV9D.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_PLAXX21D4GVB.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_PMUFO4CTQZLI.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_PN0EW10D6ETD.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_PN7E2M6AVXJ0.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_PNEMGSW53A8G.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_PNP9DII4L8D8.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_POA1QOCMX56G.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_POM2QXYM850S.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_POUYQ1HT9SLH.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_PPU215WDMQ07.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_PQ7EKSF3YWYQ.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_PQPKX7YZWGST.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_PT588EHQRUWL.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_PT8A2KRLT83Q.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_PT8A2KRLT83Q_aug.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_PU7JBTXGVL7X.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_PVDBYSB0MT32.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_PVQJKFAY3TTE.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_PWZTH8T6KKLM.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_PXRZRJ7LFAHE.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_Q0O13I7HYSAB.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_Q12DPOEXY27R.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_Q2OAF11XMZ6H.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_Q2WU5R33JD30.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_Q30ZDFDLFIPF.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_Q3W1AWYPZMPS.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_Q48Y59CQQAWD.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_Q4UYX8IK4ZCZ.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_Q8O8JX4R7TZZ.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_Q8S06EO3A73Y.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_Q9AI7TJIHI0R.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_Q9L1OF6G92AH.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_QA5I4K4CQKPS.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_QB5L7SB6TC84.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_QBC7RGX2FIPJ.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_QBKQQG5OWEB5.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_QC1EZD4VO10G.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_QCSNHR6ZLJ6S.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_QDXFMMEPS3WP.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_QEU00IQ90EGE.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_QF9YH1EPYVOS.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_QFF7H87GOPPC.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_QFLFKH46QHDD.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_QH1EVC14QT87.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_QMJZZX18OZ3V.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_QNOSJM8FKTHK.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_QO7YFMFHJT7R.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_QORH9HAFXTVF.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_QORH9HAFXTVF_aug.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_QPWMAQ8NF47D.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_QQOF5PKFBFUN.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_QQUL9494803Z.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_QSS8EUGZOKGW.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_QSWXKQ9IPILI.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_QUC83ZTNIJZE.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_QUIO9XAGZULV.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_QYUQMP6ZHDO4.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_QYXC31PLXMFA.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_R0ML936RP9F5.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_R1PN4CPLGERU.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_R2ROT8SQ4367.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_R2WEE7OCKQDO.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_R3HEXVUB4ZX6.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_R5AY1JTTZTEC.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_R7BAI20D5KQB.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_R7EG7LB9NMVJ.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_R7ICQF9M9ANV.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_R7W0FDDU3OFK.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_R9R8I2LBKSXM.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_RA159DS9A1DZ.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_RA5WM1XGEVGW.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_RBRESL1CCI5G.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_RDQVXQ62I41O.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_RFB8YUFH6KMP.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_RFIMLNNY9LTI.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_RGR461L1KGA8.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_RGS65IXPI23Z.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_RH18M03OKU7A.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_RK8UAQCKJVBH.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_RKPYDDIORE5A.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_RLJ0GL2R3SSG.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_ROUJ229IEDBS.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_RPQB34A16UJ5.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_RQLYKKNU6T3I.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_RS0JI58PUZGV.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_RSV31B4C7OQ9.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_RTWXDO1DJ4A0.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_RTXO23BFRHJW.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_RTXO23BFRHJW_aug.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_RUF8M3ZL84MT.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_RUW28WTB20MG.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_RV1S86NZAGHC.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_RV9LBWDP9XRV.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_RWMVC70AFP23.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_RXKRDZSK2B5Z.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_RZ3UPLHB921G.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_RZX9R31HIU21.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_S2MR96WPRNC6.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_S2YYFIUWFKXP.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_S36NZQPE22TR.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_S3V3OTFJ91XO.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_S43FR705S5WR.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_S4P6TMSRD5EI.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_S6GAMLEIVV5G.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_S8SY9IHI9BGZ.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_S8VGJ52JAP2S.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_S9ID5CKCR00G.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_SBN1OL9FNNEX.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_SBR3VUIYRTU3.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_SC7D6L61X7JO.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_SDA19PX5GIL4.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_SDL1QETLWIX4.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_SDQGVJAC24VL.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_SE8H4I562NN6.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_SFCKBU0MSRIL.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_SFCKBU0MSRIL_aug.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_SG9PO4A429WM.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_SJ7Z1PUID5X7.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_SJB4F3KKZU4B.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_SLFH1KJD9AFH.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_SNZXNF371LLZ.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_SO373Y40Z9KH.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_SOQQ23O18UNR.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_SOWJR5VK8C3A.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_SPXQ53LHKLRX.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_SQQG2WROQYAU.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_SRKVO4ZYEWW5.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_SRMNZVRXQZJH.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_SSQURHFIUVST.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_ST0CNDUTVF3K.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_SU4L9EAQCFQS.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_SVCENM3I062Z.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_SW5W33653SGU.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_SWH2HWXCQSOK.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_SWQ5TL0YZMSO.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_SWT0J5U1NHGI.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_SX4728JXE91K.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_SXJWBB53FUZ3.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_SYC3NJS0TBE4.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_SZSTV3N6J4TF.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_SZVQKO3R2UH2.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_T0D0K7I9GWP6.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_T0O31IMJ29X8.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_T0Z9Z9285UGR.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_T1U43W3J6BP5.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_T1ZX3CISJJAZ.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_T2A52QRAMATV.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_T2GD0HW9ONS7.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_T2HV5OUKJ4DK.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_T2L8VVW2T4TI.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_T3MIS1E28PGO.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_T4ZWRA4O536X.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_T597762PUCDM.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_T5987J8MSP06.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_T6JX45VUT2GS.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_T6OC50PES7OU.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_T6VY8K6J87ZF.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_T83Z0VU2DQ1W.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_T94CT6O9XQI2.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_TA6U7S89O1OQ.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_TAJTBA09OZ4O.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_TG7OHAPTWOYO.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_TKCPELHJDDC2.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_TKZ40C25AYE7.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_TLVI3N34XHPW.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_TLVRP2COQT0L.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_TM4C2B1JJJGT.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_TMMYNHI1OW8L.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_TMMYNHI1OW8L_aug.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_TN6BTCLHSVMM.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_TPQU97BTUFYU.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_TQLUEMY2Q25G.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_TTYEQIPFRKCA.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_TTZZXWJH4ZTG.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_TVN2BQEALVB1.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_TWJFIJMC9Z51.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_TX6WM7WQU1U3.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_TXP08C0VMMM7.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_TXWKT7DZT036.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_TY258EWZ1NGD.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_TY258EWZ1NGD_aug.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_TY3EQMZJT8BN.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_TYJ9T2J5QS49.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_TZ0FGRZT81BU.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_U01MIEGNLR1W.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_U149ROLQKF1L.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_U17FAYZIPZI5.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_U1E4KI90J9FX.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_U2OSYTNGKSVD.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_U32YS3C8BKMX.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_U3MMRWR3HES8.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_U3U7QGJQ0KDZ.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_U3U7QGJQ0KDZ_aug.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_U4QND6TEX2MX.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_U4QND6TEX2MX_aug.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_U4XD1UA3WRO2.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_U5AGH0ZV59KG.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_U5AGH0ZV59KG_aug.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_U6IBM5QRV4SD.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_U6IPH98UBPBO.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_U7H1IS0OS3Q5.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_U7XCA7JHGK8V.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_U8LRIIFVUZES.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_U916CP502ZMK.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_U9RT62E7W2WM.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_UAE74FIOV5BH.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_UAK39TRS0GAP.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_UCIN31E05XSX.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_UCSI3FAIL6CC.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_UDLTACIA53UR.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_UDUWBTFLE9TK.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_UFB87SLIQPAC.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_UG1U5JJNFDPV.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_UGR2UD3A6HMQ.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_UHD8B9QBDRI0.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_ULAAJJWXH2EF.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_ULAAJJWXH2EF_aug.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_ULBMO4ZQRDDT.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_ULIOJTEC2OGS.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_UMD42A188ROY.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_UNDBH00VTIXX.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_UNM8D8HW8LV7.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_UQ7E897TQWU0.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_UREO90MKBIA2.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_US1POZC5ZD5A.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_USDRNCSR5EH7.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_UTNF6MA1W0XW.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_UVRIEL08F2XG.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_UW0M3ED5GW6B.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_UW13V0NR132A.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_UW2SU9U08TZ3.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_UW8VLY7SLDHU.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_UWW43B64VNY4.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_UWWLN787EINO.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_UWWLN787EINO_aug.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_UXFNTKZA1DK4.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_UXFNTKZA1DK4_aug.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_UYHMFMQNFZ84.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_UYLK5N94PJOR.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_V3Y628MO4SW2.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_V4F811YKVUPJ.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_V4X3BOJGZ14C.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_V4Y9T7NKT9WI.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_V599CKCWYQST.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_V5Y3KFXIYIK4.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_V8WQ81XTHHUG.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_V9XKRZ5JNZ3N.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_VA5OGUZD1ULZ.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_VA7L875GW0PB.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_VBA6DAMAHH3L.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_VC5FU58W5T14.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_VCNU9A1CISK4.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_VEGQCRW7YZEK.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_VENXE6IA97D2.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_VENXE6IA97D2_aug.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_VF3CLGLNGBEQ.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_VHE0L2W4O4MT.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_VIK3JIGME620.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_VJ0EHKD4H6RP.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_VJBUWNBB2EZT.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_VJUZ1O618ABE.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_VKGU7JJCJ74A.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_VKJNBJSLJ8XH.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_VLQE19T19NLC.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_VLQE19T19NLC_aug.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_VLSH3ED12L3W.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_VPONLQL3UP1J.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_VQGYWODWXU3X.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_VRL6L3X6QRER.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_VSN69OIVNNF0.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_VU2LEGBOSYNI.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_VVAU043UXWZY.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_VW8VLBSVE6K0.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_VXS39VCGGHNY.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_VYCPJG1ZTHUC.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_VYRRKNG9B82Z.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_W0CW9ATG4FT1.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_W102ZG3ADDEL.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_W228OZ3AQKUP.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_W2ARLL031VVH.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_W38FNNZ2HI24.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_W3OLOKEF34X6.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_W5A2RJ0UXG0X.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_W608JEMH5LNC.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_W679KHX6H1GP.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_W6CRM9ON57HK.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_W8GBC0P7JOTF.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_W8KAPU81OE7X.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_W9FEG8PO9ZKQ.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_W9XN0XI8R60N.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WAMV1VYH611B.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WC035XYBVZI9.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WDJ1GYLMLGW2.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WDMQWXH63WP5.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WE5JK87RFC69.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WE76CN4VEGPH.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WETIPIKIRK78.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WGAS6JYUDAIW.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WGG3UJYSSLJK.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WGLOFUACVN47.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WH6B0IOVXLR4.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WHUNG7R132GD.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WIB5IAX48FV1.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WJJQJGEI0Q8A.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WJKYNNR7F6FJ.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WK1OV0YYBLT7.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WKOAAKTQJBAZ.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WLDJW6UT9NIM.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WLFMKW7TWQLM.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WP3R2DV7EZCM.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WPU5J5J8DU1D.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WPWE6YMGPA1A.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WQ7YIC8QVB5S.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WQT1VC9SC81O.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WQWAJ6SQIG2I.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WRSZCOH9T864.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WU8FKIPWYX2I.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WUGGIG9ZY2WG.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WV6AGHSUDYHV.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WV9YOFE60AGL.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WVV6HOV9STDA.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WVZQMC0OL9X0.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WWBNK5G17M61.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WXAJAKVB53KF.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WZ2UPDLXZRRH.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WZ7JKUPQWKFZ.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_WZSMHW6EMKD7.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_X0EAKE1YII1G.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_X1667ZKS92I1.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class0_X1FA0QJDP3Y5.jpg
# ...
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000459.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000460.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000461.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000462.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000463.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000464.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000465.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000466.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000467.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000468.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000469.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000470.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000471.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000472.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000473.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000474.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000475.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000476.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000477.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000478.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000479.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000480.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000481.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000482.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000483.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000484.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000485.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000486.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000487.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000488.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000489.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000490.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000491.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000492.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000493.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000494.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000495.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000496.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000497.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000498.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000499.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000500.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000501.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000502.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000503.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000504.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000505.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000506.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000507.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000508.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000509.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000510.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000511.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000512.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000513.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000514.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000515.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000516.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000517.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000518.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000519.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000520.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000521.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000522.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000523.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000524.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000525.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000526.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000527.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000528.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000529.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000530.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000531.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000532.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000533.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000534.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000535.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000536.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000537.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000538.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000539.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000540.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000541.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000542.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000543.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000544.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000545.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000546.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000547.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000548.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000549.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000550.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000551.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000552.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000553.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000554.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000555.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000556.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000557.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000558.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000559.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000560.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000561.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000562.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000563.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000564.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000565.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000566.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000567.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000568.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000569.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000570.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000571.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000572.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000573.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000574.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000575.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000576.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000577.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000578.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000579.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000580.jpg
#   inflating: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/Input-Image_Dataset/Class_1_6000581.jpg

# %% [markdown]
# # 1) Define dataset directory

# %%
# Define dataset directory
dataset_dir = "/content/drive/MyDrive/ARWAN_MAKHIJA_IRIS/Cocker_Spaniel_Emotions_Dataset/Cocker_Spaniel_Emotions_Splitted"
dataset_dir = pathlib.Path(dataset_dir)

# %% [markdown]
# ----
# ---
# ---

# %%
from google.colab import drive
import os
import shutil
import random

# %%
# Specify your source folder path in Google Drive
source_folder = '/content/drive/MyDrive/ARWAN_MAKHIJA_IRIS/Cocker_Spaniel_Emotions_Dataset/Cocker_Spaniel_Emotions_Splitted'  # CHANGE THIS to your actual folder path

# %%
# Verify the source folder exists
if not os.path.exists(source_folder):
    raise Exception(f"Source folder not found at: {source_folder}")

# %%
total_images = len(list(dataset_dir.glob('*/*.jpg'))) + len(list(dataset_dir.glob('*/*.png')))
print(f"Total images in dataset: {total_images}")

# Get all image files from the source folder (assuming common image extensions)
image_extensions = ('.jpg', '.jpeg', '.png', '.gif', '.bmp')
all_images = [f for f in os.listdir(source_folder) if f.lower().endswith(image_extensions)]
# Out:
# Total images in dataset: 0

# %%
# Check if there are enough images
total_needed = 700 * 8
if len(all_images) < total_needed:
    raise Exception(f"Not enough images. Need {total_needed} but found {len(all_images)}")

print(len(all_images))
# Out:
# 6012

# %%
# Step 2: Create 8 subfolders
subfolder_names = [
    "Class1_Sad", "Class1_Happy", "Class1_Stress", "Class1_Restless",
    "Class1_Love", "Class1_Lonely", "Class1_Tired", "Class1_Normal"
]

# %%
# Create a parent folder for the subfolders (you can change this)
parent_folder = os.path.join(os.path.dirname(source_folder), '8_Emotion_Images')
os.makedirs(parent_folder, exist_ok=True)

# %%
# Create the subfolders
for folder_name in subfolder_names:
    folder_path = os.path.join(parent_folder, folder_name)
    os.makedirs(folder_path, exist_ok=True)
    print(f"Created folder: {folder_path}")
# Out:
# Created folder: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/8_Emotion_Images/Class1_Sad
# Created folder: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/8_Emotion_Images/Class1_Happy
# Created folder: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/8_Emotion_Images/Class1_Stress
# Created folder: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/8_Emotion_Images/Class1_Restless
# Created folder: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/8_Emotion_Images/Class1_Love
# Created folder: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/8_Emotion_Images/Class1_Lonely
# Created folder: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/8_Emotion_Images/Class1_Tired
# Created folder: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/8_Emotion_Images/Class1_Normal

# %%
# Step 3: Copy 700 random images to each subfolder
random.shuffle(all_images)  # Shuffle to ensure random distribution

for i, folder_name in enumerate(subfolder_names):
    folder_path = os.path.join(parent_folder, folder_name)
    start_index = i * 700
    end_index = start_index + 700
    selected_images = all_images[start_index:end_index]

    for img in selected_images:
        src_path = os.path.join(source_folder, img)
        dst_path = os.path.join(folder_path, img)
        shutil.copy2(src_path, dst_path)

    print(f"Copied {len(selected_images)} images to {folder_name}")
# Out:
# Copied 700 images to Class1_Sad
# Copied 700 images to Class1_Happy
# Copied 700 images to Class1_Stress
# Copied 700 images to Class1_Restless
# Copied 700 images to Class1_Love
# Copied 700 images to Class1_Lonely
# Copied 700 images to Class1_Tired
# Copied 700 images to Class1_Normal

# %%
print("\nProcess completed successfully!")
print(f"Total images distributed: {700 * 8}")
print(f"Parent folder with subfolders created at: {parent_folder}")
# Out:
# Process completed successfully!
# Total images distributed: 5600
# Parent folder with subfolders created at: /content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Input_Image_Dataset/8_Emotion_Images

# %%
# Define dataset directory
dataset_dir = "/content/drive/MyDrive/ARWAN_MAKHIJA_IRIS/Cocker_Spaniel_Emotions_Dataset/Cocker_Spaniel_Emotions_Splitted"
dataset_dir = pathlib.Path(dataset_dir)

# Count total images
total_images = len(list(dataset_dir.glob('*/*.jpg'))) + len(list(dataset_dir.glob('*/*.png')))
print(f"Total images in dataset: {total_images}")
# Out:
# Total images in dataset: 0

# %%
# Define emotion classes and labels
#emotion_classes = ["Sad", "Happy", "Stress", "Restless", "Normal", "Love", "Unhappy", "Tired"]
emotion_classes = ["Class1_Sad", "Class1_Happy", "Class1_Stress", "Class1_Restless", "Class1_Love", "Class1_Lonely", "Class1_Tired", "Class1_Normal"]
class_labels = {cls: idx for idx, cls in enumerate(emotion_classes)}
image_counts = {}
image_paths = {}

# %%
# Count images per class
for cls in emotion_classes:
    count = len(list(dataset_dir.glob(f'{cls}/*')))
    paths = list(dataset_dir.glob(f'{cls}/*'))
    image_counts[cls] = count
    image_paths[cls] = paths
    print(f"{cls}: {count} images")

# %%
# Plot class distribution
plt.figure(figsize=(10, 6))
plt.bar(image_counts.keys(), image_counts.values(), color='orange')
plt.xlabel('Emotion Class')
plt.ylabel('Number of Images')
plt.title('Distribution of Cocker Spaniel Emotion Images')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Split dataset into train, validation, and test sets
def split_dataset(dataset_dir, output_dir, train_ratio=0.7, val_ratio=0.15, test_ratio=0.15):
    for split in ['train', 'val', 'test']:
        os.makedirs(os.path.join(output_dir, split), exist_ok=True)

    for cls in emotion_classes:
        class_path = os.path.join(dataset_dir, cls)
        images = os.listdir(class_path)
        random.shuffle(images)

        total_images = len(images)
        train_end = int(train_ratio * total_images)
        val_end = train_end + int(val_ratio * total_images)

        train_images = images[:train_end]
        val_images = images[train_end:val_end]
        test_images = images[val_end:]

        def copy_images(image_list, split):
            split_class_dir = os.path.join(output_dir, split, cls)
            os.makedirs(split_class_dir, exist_ok=True)
            for img in image_list:
                src = os.path.join(class_path, img)
                dst = os.path.join(split_class_dir, img)
                shutil.copy(src, dst)

        copy_images(train_images, 'train')
        copy_images(val_images, 'val')
        copy_images(test_images, 'test')

splitted_dataset_dir = '/content/drive/MyDrive/Cocker_Spaniel_Emotions_Dataset/Cocker_Spaniel_Emotions_Splitted'
split_dataset(dataset_dir, splitted_dataset_dir)
print("✅ Dataset successfully split into training, validation, and testing sets!")
# Out:
# ✅ Dataset successfully split into training, validation, and testing sets!

# %% [markdown]
# -----------
# Post Dataset Split
# ----------
# --------

# %%
splitted_dataset_dir = '/content/drive/MyDrive/ARWAN_MAKHIJA_IRIS/Cocker_Spaniel_Emotions_Dataset/Cocker_Spaniel_Emotions_Splitted'
print("✅ Dataset successfully split into training, validation, and testing sets!")
# Out:
# ✅ Dataset successfully split into training, validation, and testing sets!

# %%
from google.colab import drive
import os
from tqdm import tqdm


# Define the parent folder path
parent_folder = '/content/drive/MyDrive/ARWAN_MAKHIJA_IRIS/Cocker_Spaniel_Emotions_Dataset/Cocker_Spaniel_Emotions_Splitted'

def count_jpg_files(folder_path):
    """Count JPG files in a given folder"""
    return len([f for f in os.listdir(folder_path) if f.lower().endswith('.jpg')])

def get_all_subfolders(root_path, max_depth=2):
    """Get all subfolders up to specified depth"""
    subfolders = []
    for root, dirs, _ in os.walk(root_path):
        current_depth = root[len(root_path):].count(os.sep)
        if current_depth < max_depth:
            for d in dirs:
                subfolders.append(os.path.join(root, d))
    return subfolders

# Verify the parent folder exists
if not os.path.exists(parent_folder):
    raise Exception(f"Parent folder not found at: {parent_folder}")

# Get all subfolders up to 2 levels deep
print("Scanning folder structure...")
all_subfolders = get_all_subfolders(parent_folder, max_depth=2)

# Count JPG files in each subfolder
print("\nCounting JPG files in each subfolder:")
counts = {}
for folder in tqdm(all_subfolders, desc="Processing folders"):
    counts[folder] = count_jpg_files(folder)

# Display results in a hierarchical format
print("\nJPG File Counts (2 levels deep):")
print("=" * 40)
current_parent = None

for folder in sorted(counts.keys()):
    parts = folder.replace(parent_folder, '').split(os.sep)
    level = len(parts) - 1

    if level == 1:
        print(f"\n{parts[1]}/")
        print("-" * (len(parts[1]) + 1))
    elif level == 2:
        print(f"  ├── {parts[2]}: {counts[folder]} JPGs")

total = sum(counts.values())
print("\n" + "=" * 40)
print(f"TOTAL JPG FILES: {total}")
# Out:
# Scanning folder structure...
#
# Counting JPG files in each subfolder:
# Processing folders: 100%|██████████| 27/27 [00:00<00:00, 354.11it/s]
# JPG File Counts (2 levels deep):
# ========================================
#
# test/
# -----
#   ├── Class1_Happy: 212 JPGs
#   ├── Class1_Lonely: 210 JPGs
#   ├── Class1_Love: 211 JPGs
#   ├── Class1_Normal: 209 JPGs
#   ├── Class1_Restless: 209 JPGs
#   ├── Class1_Sad: 209 JPGs
#   ├── Class1_Stress: 211 JPGs
#   ├── Class1_Tired: 212 JPGs
#
# train/
# ------
#   ├── Class1_Happy: 941 JPGs
#   ├── Class1_Lonely: 932 JPGs
#   ├── Class1_Love: 942 JPGs
#   ├── Class1_Normal: 934 JPGs
#   ├── Class1_Restless: 933 JPGs
#   ├── Class1_Sad: 948 JPGs
#   ├── Class1_Stress: 944 JPGs
#   ├── Class1_Tired: 941 JPGs
#
# val/
# ----
#   ├── Class1_Happy: 206 JPGs
#   ├── Class1_Lonely: 207 JPGs
#   ├── Class1_Love: 210 JPGs
#   ├── Class1_Normal: 209 JPGs
#   ├── Class1_Restless: 208 JPGs
#   ├── Class1_Sad: 208 JPGs
#   ├── Class1_Stress: 210 JPGs
#   ├── Class1_Tired: 209 JPGs
#
# ========================================
# TOTAL JPG FILES: 10865

# %%
# Verify split counts
for split in ['train', 'val', 'test']:
    print(f"\n📂 {split.upper()} SET:")
    split_path = os.path.join(splitted_dataset_dir, split)
    for cls in emotion_classes:
        class_path = os.path.join(split_path, cls)
        num_images = len(os.listdir(class_path)) if os.path.exists(class_path) else 0
        print(f"   - {cls}: {num_images} images")
# Out:
# 📂 TRAIN SET:
#    - Class1_Sad: 948 images
#    - Class1_Happy: 941 images
#    - Class1_Stress: 944 images
#    - Class1_Restless: 933 images
#    - Class1_Love: 942 images
#    - Class1_Lonely: 932 images
#    - Class1_Tired: 941 images
#    - Class1_Normal: 934 images
#
# 📂 VAL SET:
#    - Class1_Sad: 208 images
#    - Class1_Happy: 206 images
#    - Class1_Stress: 210 images
#    - Class1_Restless: 208 images
#    - Class1_Love: 210 images
#    - Class1_Lonely: 207 images
#    - Class1_Tired: 209 images
#    - Class1_Normal: 209 images
#
# 📂 TEST SET:
#    - Class1_Sad: 209 images
#    - Class1_Happy: 212 images
#    - Class1_Stress: 211 images
#    - Class1_Restless: 209 images
#    - Class1_Love: 211 images
#    - Class1_Lonely: 210 images
#    - Class1_Tired: 212 images
#    - Class1_Normal: 209 images

# %%
# Data augmentation and generators
IMG_HEIGHT, IMG_WIDTH, BATCH_SIZE = 224, 224, 32
NUM_CLASSES = 8

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    fill_mode='nearest'
)

val_test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    f'{splitted_dataset_dir}/train',
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

val_generator = val_test_datagen.flow_from_directory(
    f'{splitted_dataset_dir}/val',
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

test_generator = val_test_datagen.flow_from_directory(
    f'{splitted_dataset_dir}/test',
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print("\nClass indices:", train_generator.class_indices)
# Out:
# Found 7515 images belonging to 8 classes.
# Found 1667 images belonging to 8 classes.
# Found 1683 images belonging to 8 classes.
#
# Class indices: {'Class1_Happy': 0, 'Class1_Lonely': 1, 'Class1_Love': 2, 'Class1_Normal': 3, 'Class1_Restless': 4, 'Class1_Sad': 5, 'Class1_Stress': 6, 'Class1_Tired': 7}

# %% [markdown]
# ####Define EfficientNetB7-based model

# %%
# Define EfficientNetB7-based model
def create_EfficientNetB7_model():
    base_model = EfficientNetB7(weights='imagenet', include_top=False, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))
    base_model.trainable = False  # Freeze base model layers

    inputs = base_model.input
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.3)(x)
    outputs = Dense(NUM_CLASSES, activation='softmax')(x)

    model = Model(inputs=inputs, outputs=outputs)
    return model

model = create_EfficientNetB7_model()
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb7_notop.h5
# 258076736/258076736 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 224, 224,  │          0 │ input_layer[0][0] │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalization       │ (None, 224, 224,  │          7 │ rescaling[0][0]   │
# │ (Normalization)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_1         │ (None, 224, 224,  │          0 │ normalization[0]… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv_pad       │ (None, 225, 225,  │          0 │ rescaling_1[0][0] │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv (Conv2D)  │ (None, 112, 112,  │      1,728 │ stem_conv_pad[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_bn             │ (None, 112, 112,  │        256 │ stem_conv[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_activation     │ (None, 112, 112,  │          0 │ stem_bn[0][0]     │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_dwconv      │ (None, 112, 112,  │        576 │ stem_activation[… │
# │ (DepthwiseConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_bn          │ (None, 112, 112,  │        256 │ block1a_dwconv[0… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_activation  │ (None, 112, 112,  │          0 │ block1a_bn[0][0]  │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_squeeze  │ (None, 64)        │          0 │ block1a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_reshape  │ (None, 1, 1, 64)  │          0 │ block1a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_reduce   │ (None, 1, 1, 16)  │      1,040 │ block1a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_expand   │ (None, 1, 1, 64)  │      1,088 │ block1a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_excite   │ (None, 112, 112,  │          0 │ block1a_activati… │
# │ (Multiply)          │ 64)               │            │ block1a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_co… │ (None, 112, 112,  │      2,048 │ block1a_se_excit… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_bn  │ (None, 112, 112,  │        128 │ block1a_project_… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_dwconv      │ (None, 112, 112,  │        288 │ block1a_project_… │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_bn          │ (None, 112, 112,  │        128 │ block1b_dwconv[0… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_activation  │ (None, 112, 112,  │          0 │ block1b_bn[0][0]  │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_se_squeeze  │ (None, 32)        │          0 │ block1b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_se_reshape  │ (None, 1, 1, 32)  │          0 │ block1b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_se_reduce   │ (None, 1, 1, 8)   │        264 │ block1b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_se_expand   │ (None, 1, 1, 32)  │        288 │ block1b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_se_excite   │ (None, 112, 112,  │          0 │ block1b_activati… │
# │ (Multiply)          │ 32)               │            │ block1b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_project_co… │ (None, 112, 112,  │      1,024 │ block1b_se_excit… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_project_bn  │ (None, 112, 112,  │        128 │ block1b_project_… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_drop        │ (None, 112, 112,  │          0 │ block1b_project_… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_add (Add)   │ (None, 112, 112,  │          0 │ block1b_drop[0][… │
# │                     │ 32)               │            │ block1a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1c_dwconv      │ (None, 112, 112,  │        288 │ block1b_add[0][0] │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1c_bn          │ (None, 112, 112,  │        128 │ block1c_dwconv[0… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1c_activation  │ (None, 112, 112,  │          0 │ block1c_bn[0][0]  │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1c_se_squeeze  │ (None, 32)        │          0 │ block1c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1c_se_reshape  │ (None, 1, 1, 32)  │          0 │ block1c_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1c_se_reduce   │ (None, 1, 1, 8)   │        264 │ block1c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1c_se_expand   │ (None, 1, 1, 32)  │        288 │ block1c_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1c_se_excite   │ (None, 112, 112,  │          0 │ block1c_activati… │
# │ (Multiply)          │ 32)               │            │ block1c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1c_project_co… │ (None, 112, 112,  │      1,024 │ block1c_se_excit… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1c_project_bn  │ (None, 112, 112,  │        128 │ block1c_project_… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1c_drop        │ (None, 112, 112,  │          0 │ block1c_project_… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1c_add (Add)   │ (None, 112, 112,  │          0 │ block1c_drop[0][… │
# │                     │ 32)               │            │ block1b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1d_dwconv      │ (None, 112, 112,  │        288 │ block1c_add[0][0] │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1d_bn          │ (None, 112, 112,  │        128 │ block1d_dwconv[0… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1d_activation  │ (None, 112, 112,  │          0 │ block1d_bn[0][0]  │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1d_se_squeeze  │ (None, 32)        │          0 │ block1d_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1d_se_reshape  │ (None, 1, 1, 32)  │          0 │ block1d_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1d_se_reduce   │ (None, 1, 1, 8)   │        264 │ block1d_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1d_se_expand   │ (None, 1, 1, 32)  │        288 │ block1d_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1d_se_excite   │ (None, 112, 112,  │          0 │ block1d_activati… │
# │ (Multiply)          │ 32)               │            │ block1d_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1d_project_co… │ (None, 112, 112,  │      1,024 │ block1d_se_excit… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1d_project_bn  │ (None, 112, 112,  │        128 │ block1d_project_… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1d_drop        │ (None, 112, 112,  │          0 │ block1d_project_… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1d_add (Add)   │ (None, 112, 112,  │          0 │ block1d_drop[0][… │
# │                     │ 32)               │            │ block1c_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_conv │ (None, 112, 112,  │      6,144 │ block1d_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_bn   │ (None, 112, 112,  │        768 │ block2a_expand_c… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_act… │ (None, 112, 112,  │          0 │ block2a_expand_b… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_dwconv_pad  │ (None, 113, 113,  │          0 │ block2a_expand_a… │
# │ (ZeroPadding2D)     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_dwconv      │ (None, 56, 56,    │      1,728 │ block2a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_bn          │ (None, 56, 56,    │        768 │ block2a_dwconv[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_activation  │ (None, 56, 56,    │          0 │ block2a_bn[0][0]  │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_squeeze  │ (None, 192)       │          0 │ block2a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_reshape  │ (None, 1, 1, 192) │          0 │ block2a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_reduce   │ (None, 1, 1, 8)   │      1,544 │ block2a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_expand   │ (None, 1, 1, 192) │      1,728 │ block2a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_excite   │ (None, 56, 56,    │          0 │ block2a_activati… │
# │ (Multiply)          │ 192)              │            │ block2a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_co… │ (None, 56, 56,    │      9,216 │ block2a_se_excit… │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_bn  │ (None, 56, 56,    │        192 │ block2a_project_… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_conv │ (None, 56, 56,    │     13,824 │ block2a_project_… │
# │ (Conv2D)            │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_bn   │ (None, 56, 56,    │      1,152 │ block2b_expand_c… │
# │ (BatchNormalizatio… │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_act… │ (None, 56, 56,    │          0 │ block2b_expand_b… │
# │ (Activation)        │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_dwconv      │ (None, 56, 56,    │      2,592 │ block2b_expand_a… │
# │ (DepthwiseConv2D)   │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_bn          │ (None, 56, 56,    │      1,152 │ block2b_dwconv[0… │
# │ (BatchNormalizatio… │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_activation  │ (None, 56, 56,    │          0 │ block2b_bn[0][0]  │
# │ (Activation)        │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_squeeze  │ (None, 288)       │          0 │ block2b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_reshape  │ (None, 1, 1, 288) │          0 │ block2b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_reduce   │ (None, 1, 1, 12)  │      3,468 │ block2b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_expand   │ (None, 1, 1, 288) │      3,744 │ block2b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_excite   │ (None, 56, 56,    │          0 │ block2b_activati… │
# │ (Multiply)          │ 288)              │            │ block2b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_project_co… │ (None, 56, 56,    │     13,824 │ block2b_se_excit… │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_project_bn  │ (None, 56, 56,    │        192 │ block2b_project_… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_drop        │ (None, 56, 56,    │          0 │ block2b_project_… │
# │ (Dropout)           │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_add (Add)   │ (None, 56, 56,    │          0 │ block2b_drop[0][… │
# │                     │ 48)               │            │ block2a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_expand_conv │ (None, 56, 56,    │     13,824 │ block2b_add[0][0] │
# │ (Conv2D)            │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_expand_bn   │ (None, 56, 56,    │      1,152 │ block2c_expand_c… │
# │ (BatchNormalizatio… │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_expand_act… │ (None, 56, 56,    │          0 │ block2c_expand_b… │
# │ (Activation)        │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_dwconv      │ (None, 56, 56,    │      2,592 │ block2c_expand_a… │
# │ (DepthwiseConv2D)   │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_bn          │ (None, 56, 56,    │      1,152 │ block2c_dwconv[0… │
# │ (BatchNormalizatio… │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_activation  │ (None, 56, 56,    │          0 │ block2c_bn[0][0]  │
# │ (Activation)        │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_se_squeeze  │ (None, 288)       │          0 │ block2c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_se_reshape  │ (None, 1, 1, 288) │          0 │ block2c_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_se_reduce   │ (None, 1, 1, 12)  │      3,468 │ block2c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_se_expand   │ (None, 1, 1, 288) │      3,744 │ block2c_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_se_excite   │ (None, 56, 56,    │          0 │ block2c_activati… │
# │ (Multiply)          │ 288)              │            │ block2c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_project_co… │ (None, 56, 56,    │     13,824 │ block2c_se_excit… │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_project_bn  │ (None, 56, 56,    │        192 │ block2c_project_… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_drop        │ (None, 56, 56,    │          0 │ block2c_project_… │
# │ (Dropout)           │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_add (Add)   │ (None, 56, 56,    │          0 │ block2c_drop[0][… │
# │                     │ 48)               │            │ block2b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_expand_conv │ (None, 56, 56,    │     13,824 │ block2c_add[0][0] │
# │ (Conv2D)            │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_expand_bn   │ (None, 56, 56,    │      1,152 │ block2d_expand_c… │
# │ (BatchNormalizatio… │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_expand_act… │ (None, 56, 56,    │          0 │ block2d_expand_b… │
# │ (Activation)        │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_dwconv      │ (None, 56, 56,    │      2,592 │ block2d_expand_a… │
# │ (DepthwiseConv2D)   │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_bn          │ (None, 56, 56,    │      1,152 │ block2d_dwconv[0… │
# │ (BatchNormalizatio… │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_activation  │ (None, 56, 56,    │          0 │ block2d_bn[0][0]  │
# │ (Activation)        │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_se_squeeze  │ (None, 288)       │          0 │ block2d_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_se_reshape  │ (None, 1, 1, 288) │          0 │ block2d_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_se_reduce   │ (None, 1, 1, 12)  │      3,468 │ block2d_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_se_expand   │ (None, 1, 1, 288) │      3,744 │ block2d_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_se_excite   │ (None, 56, 56,    │          0 │ block2d_activati… │
# │ (Multiply)          │ 288)              │            │ block2d_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_project_co… │ (None, 56, 56,    │     13,824 │ block2d_se_excit… │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_project_bn  │ (None, 56, 56,    │        192 │ block2d_project_… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_drop        │ (None, 56, 56,    │          0 │ block2d_project_… │
# │ (Dropout)           │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_add (Add)   │ (None, 56, 56,    │          0 │ block2d_drop[0][… │
# │                     │ 48)               │            │ block2c_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2e_expand_conv │ (None, 56, 56,    │     13,824 │ block2d_add[0][0] │
# │ (Conv2D)            │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2e_expand_bn   │ (None, 56, 56,    │      1,152 │ block2e_expand_c… │
# │ (BatchNormalizatio… │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2e_expand_act… │ (None, 56, 56,    │          0 │ block2e_expand_b… │
# │ (Activation)        │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2e_dwconv      │ (None, 56, 56,    │      2,592 │ block2e_expand_a… │
# │ (DepthwiseConv2D)   │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2e_bn          │ (None, 56, 56,    │      1,152 │ block2e_dwconv[0… │
# │ (BatchNormalizatio… │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2e_activation  │ (None, 56, 56,    │          0 │ block2e_bn[0][0]  │
# │ (Activation)        │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2e_se_squeeze  │ (None, 288)       │          0 │ block2e_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2e_se_reshape  │ (None, 1, 1, 288) │          0 │ block2e_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2e_se_reduce   │ (None, 1, 1, 12)  │      3,468 │ block2e_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2e_se_expand   │ (None, 1, 1, 288) │      3,744 │ block2e_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2e_se_excite   │ (None, 56, 56,    │          0 │ block2e_activati… │
# │ (Multiply)          │ 288)              │            │ block2e_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2e_project_co… │ (None, 56, 56,    │     13,824 │ block2e_se_excit… │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2e_project_bn  │ (None, 56, 56,    │        192 │ block2e_project_… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2e_drop        │ (None, 56, 56,    │          0 │ block2e_project_… │
# │ (Dropout)           │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2e_add (Add)   │ (None, 56, 56,    │          0 │ block2e_drop[0][… │
# │                     │ 48)               │            │ block2d_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2f_expand_conv │ (None, 56, 56,    │     13,824 │ block2e_add[0][0] │
# │ (Conv2D)            │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2f_expand_bn   │ (None, 56, 56,    │      1,152 │ block2f_expand_c… │
# │ (BatchNormalizatio… │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2f_expand_act… │ (None, 56, 56,    │          0 │ block2f_expand_b… │
# │ (Activation)        │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2f_dwconv      │ (None, 56, 56,    │      2,592 │ block2f_expand_a… │
# │ (DepthwiseConv2D)   │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2f_bn          │ (None, 56, 56,    │      1,152 │ block2f_dwconv[0… │
# │ (BatchNormalizatio… │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2f_activation  │ (None, 56, 56,    │          0 │ block2f_bn[0][0]  │
# │ (Activation)        │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2f_se_squeeze  │ (None, 288)       │          0 │ block2f_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2f_se_reshape  │ (None, 1, 1, 288) │          0 │ block2f_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2f_se_reduce   │ (None, 1, 1, 12)  │      3,468 │ block2f_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2f_se_expand   │ (None, 1, 1, 288) │      3,744 │ block2f_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2f_se_excite   │ (None, 56, 56,    │          0 │ block2f_activati… │
# │ (Multiply)          │ 288)              │            │ block2f_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2f_project_co… │ (None, 56, 56,    │     13,824 │ block2f_se_excit… │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2f_project_bn  │ (None, 56, 56,    │        192 │ block2f_project_… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2f_drop        │ (None, 56, 56,    │          0 │ block2f_project_… │
# │ (Dropout)           │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2f_add (Add)   │ (None, 56, 56,    │          0 │ block2f_drop[0][… │
# │                     │ 48)               │            │ block2e_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2g_expand_conv │ (None, 56, 56,    │     13,824 │ block2f_add[0][0] │
# │ (Conv2D)            │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2g_expand_bn   │ (None, 56, 56,    │      1,152 │ block2g_expand_c… │
# │ (BatchNormalizatio… │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2g_expand_act… │ (None, 56, 56,    │          0 │ block2g_expand_b… │
# │ (Activation)        │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2g_dwconv      │ (None, 56, 56,    │      2,592 │ block2g_expand_a… │
# │ (DepthwiseConv2D)   │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2g_bn          │ (None, 56, 56,    │      1,152 │ block2g_dwconv[0… │
# │ (BatchNormalizatio… │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2g_activation  │ (None, 56, 56,    │          0 │ block2g_bn[0][0]  │
# │ (Activation)        │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2g_se_squeeze  │ (None, 288)       │          0 │ block2g_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2g_se_reshape  │ (None, 1, 1, 288) │          0 │ block2g_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2g_se_reduce   │ (None, 1, 1, 12)  │      3,468 │ block2g_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2g_se_expand   │ (None, 1, 1, 288) │      3,744 │ block2g_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2g_se_excite   │ (None, 56, 56,    │          0 │ block2g_activati… │
# │ (Multiply)          │ 288)              │            │ block2g_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2g_project_co… │ (None, 56, 56,    │     13,824 │ block2g_se_excit… │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2g_project_bn  │ (None, 56, 56,    │        192 │ block2g_project_… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2g_drop        │ (None, 56, 56,    │          0 │ block2g_project_… │
# │ (Dropout)           │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2g_add (Add)   │ (None, 56, 56,    │          0 │ block2g_drop[0][… │
# │                     │ 48)               │            │ block2f_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_conv │ (None, 56, 56,    │     13,824 │ block2g_add[0][0] │
# │ (Conv2D)            │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_bn   │ (None, 56, 56,    │      1,152 │ block3a_expand_c… │
# │ (BatchNormalizatio… │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_act… │ (None, 56, 56,    │          0 │ block3a_expand_b… │
# │ (Activation)        │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_dwconv_pad  │ (None, 59, 59,    │          0 │ block3a_expand_a… │
# │ (ZeroPadding2D)     │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_dwconv      │ (None, 28, 28,    │      7,200 │ block3a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_bn          │ (None, 28, 28,    │      1,152 │ block3a_dwconv[0… │
# │ (BatchNormalizatio… │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_activation  │ (None, 28, 28,    │          0 │ block3a_bn[0][0]  │
# │ (Activation)        │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_squeeze  │ (None, 288)       │          0 │ block3a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_reshape  │ (None, 1, 1, 288) │          0 │ block3a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_reduce   │ (None, 1, 1, 12)  │      3,468 │ block3a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_expand   │ (None, 1, 1, 288) │      3,744 │ block3a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_excite   │ (None, 28, 28,    │          0 │ block3a_activati… │
# │ (Multiply)          │ 288)              │            │ block3a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_co… │ (None, 28, 28,    │     23,040 │ block3a_se_excit… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_bn  │ (None, 28, 28,    │        320 │ block3a_project_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_conv │ (None, 28, 28,    │     38,400 │ block3a_project_… │
# │ (Conv2D)            │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_bn   │ (None, 28, 28,    │      1,920 │ block3b_expand_c… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_act… │ (None, 28, 28,    │          0 │ block3b_expand_b… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_dwconv      │ (None, 28, 28,    │     12,000 │ block3b_expand_a… │
# │ (DepthwiseConv2D)   │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_bn          │ (None, 28, 28,    │      1,920 │ block3b_dwconv[0… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_activation  │ (None, 28, 28,    │          0 │ block3b_bn[0][0]  │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_squeeze  │ (None, 480)       │          0 │ block3b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_reshape  │ (None, 1, 1, 480) │          0 │ block3b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_reduce   │ (None, 1, 1, 20)  │      9,620 │ block3b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_expand   │ (None, 1, 1, 480) │     10,080 │ block3b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_excite   │ (None, 28, 28,    │          0 │ block3b_activati… │
# │ (Multiply)          │ 480)              │            │ block3b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_project_co… │ (None, 28, 28,    │     38,400 │ block3b_se_excit… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_project_bn  │ (None, 28, 28,    │        320 │ block3b_project_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_drop        │ (None, 28, 28,    │          0 │ block3b_project_… │
# │ (Dropout)           │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_add (Add)   │ (None, 28, 28,    │          0 │ block3b_drop[0][… │
# │                     │ 80)               │            │ block3a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_expand_conv │ (None, 28, 28,    │     38,400 │ block3b_add[0][0] │
# │ (Conv2D)            │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_expand_bn   │ (None, 28, 28,    │      1,920 │ block3c_expand_c… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_expand_act… │ (None, 28, 28,    │          0 │ block3c_expand_b… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_dwconv      │ (None, 28, 28,    │     12,000 │ block3c_expand_a… │
# │ (DepthwiseConv2D)   │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_bn          │ (None, 28, 28,    │      1,920 │ block3c_dwconv[0… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_activation  │ (None, 28, 28,    │          0 │ block3c_bn[0][0]  │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_se_squeeze  │ (None, 480)       │          0 │ block3c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_se_reshape  │ (None, 1, 1, 480) │          0 │ block3c_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_se_reduce   │ (None, 1, 1, 20)  │      9,620 │ block3c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_se_expand   │ (None, 1, 1, 480) │     10,080 │ block3c_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_se_excite   │ (None, 28, 28,    │          0 │ block3c_activati… │
# │ (Multiply)          │ 480)              │            │ block3c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_project_co… │ (None, 28, 28,    │     38,400 │ block3c_se_excit… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_project_bn  │ (None, 28, 28,    │        320 │ block3c_project_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_drop        │ (None, 28, 28,    │          0 │ block3c_project_… │
# │ (Dropout)           │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_add (Add)   │ (None, 28, 28,    │          0 │ block3c_drop[0][… │
# │                     │ 80)               │            │ block3b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_expand_conv │ (None, 28, 28,    │     38,400 │ block3c_add[0][0] │
# │ (Conv2D)            │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_expand_bn   │ (None, 28, 28,    │      1,920 │ block3d_expand_c… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_expand_act… │ (None, 28, 28,    │          0 │ block3d_expand_b… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_dwconv      │ (None, 28, 28,    │     12,000 │ block3d_expand_a… │
# │ (DepthwiseConv2D)   │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6m_project_bn  │ (None, 7, 7, 384) │      1,536 │ block6m_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6m_drop        │ (None, 7, 7, 384) │          0 │ block6m_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6m_add (Add)   │ (None, 7, 7, 384) │          0 │ block6m_drop[0][… │
# │                     │                   │            │ block6l_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_expand_conv │ (None, 7, 7,      │    884,736 │ block6m_add[0][0] │
# │ (Conv2D)            │ 2304)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_expand_bn   │ (None, 7, 7,      │      9,216 │ block7a_expand_c… │
# │ (BatchNormalizatio… │ 2304)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_expand_act… │ (None, 7, 7,      │          0 │ block7a_expand_b… │
# │ (Activation)        │ 2304)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_dwconv      │ (None, 7, 7,      │     20,736 │ block7a_expand_a… │
# │ (DepthwiseConv2D)   │ 2304)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_bn          │ (None, 7, 7,      │      9,216 │ block7a_dwconv[0… │
# │ (BatchNormalizatio… │ 2304)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_activation  │ (None, 7, 7,      │          0 │ block7a_bn[0][0]  │
# │ (Activation)        │ 2304)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_squeeze  │ (None, 2304)      │          0 │ block7a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_reshape  │ (None, 1, 1,      │          0 │ block7a_se_squee… │
# │ (Reshape)           │ 2304)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_reduce   │ (None, 1, 1, 96)  │    221,280 │ block7a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_expand   │ (None, 1, 1,      │    223,488 │ block7a_se_reduc… │
# │ (Conv2D)            │ 2304)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_excite   │ (None, 7, 7,      │          0 │ block7a_activati… │
# │ (Multiply)          │ 2304)             │            │ block7a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_project_co… │ (None, 7, 7, 640) │  1,474,560 │ block7a_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_project_bn  │ (None, 7, 7, 640) │      2,560 │ block7a_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_expand_conv │ (None, 7, 7,      │  2,457,600 │ block7a_project_… │
# │ (Conv2D)            │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_expand_bn   │ (None, 7, 7,      │     15,360 │ block7b_expand_c… │
# │ (BatchNormalizatio… │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_expand_act… │ (None, 7, 7,      │          0 │ block7b_expand_b… │
# │ (Activation)        │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_dwconv      │ (None, 7, 7,      │     34,560 │ block7b_expand_a… │
# │ (DepthwiseConv2D)   │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_bn          │ (None, 7, 7,      │     15,360 │ block7b_dwconv[0… │
# │ (BatchNormalizatio… │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_activation  │ (None, 7, 7,      │          0 │ block7b_bn[0][0]  │
# │ (Activation)        │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_se_squeeze  │ (None, 3840)      │          0 │ block7b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_se_reshape  │ (None, 1, 1,      │          0 │ block7b_se_squee… │
# │ (Reshape)           │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_se_reduce   │ (None, 1, 1, 160) │    614,560 │ block7b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_se_expand   │ (None, 1, 1,      │    618,240 │ block7b_se_reduc… │
# │ (Conv2D)            │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_se_excite   │ (None, 7, 7,      │          0 │ block7b_activati… │
# │ (Multiply)          │ 3840)             │            │ block7b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_project_co… │ (None, 7, 7, 640) │  2,457,600 │ block7b_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_project_bn  │ (None, 7, 7, 640) │      2,560 │ block7b_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_drop        │ (None, 7, 7, 640) │          0 │ block7b_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_add (Add)   │ (None, 7, 7, 640) │          0 │ block7b_drop[0][… │
# │                     │                   │            │ block7a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7c_expand_conv │ (None, 7, 7,      │  2,457,600 │ block7b_add[0][0] │
# │ (Conv2D)            │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7c_expand_bn   │ (None, 7, 7,      │     15,360 │ block7c_expand_c… │
# │ (BatchNormalizatio… │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7c_expand_act… │ (None, 7, 7,      │          0 │ block7c_expand_b… │
# │ (Activation)        │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7c_dwconv      │ (None, 7, 7,      │     34,560 │ block7c_expand_a… │
# │ (DepthwiseConv2D)   │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7c_bn          │ (None, 7, 7,      │     15,360 │ block7c_dwconv[0… │
# │ (BatchNormalizatio… │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7c_activation  │ (None, 7, 7,      │          0 │ block7c_bn[0][0]  │
# │ (Activation)        │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7c_se_squeeze  │ (None, 3840)      │          0 │ block7c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7c_se_reshape  │ (None, 1, 1,      │          0 │ block7c_se_squee… │
# │ (Reshape)           │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7c_se_reduce   │ (None, 1, 1, 160) │    614,560 │ block7c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7c_se_expand   │ (None, 1, 1,      │    618,240 │ block7c_se_reduc… │
# │ (Conv2D)            │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7c_se_excite   │ (None, 7, 7,      │          0 │ block7c_activati… │
# │ (Multiply)          │ 3840)             │            │ block7c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7c_project_co… │ (None, 7, 7, 640) │  2,457,600 │ block7c_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7c_project_bn  │ (None, 7, 7, 640) │      2,560 │ block7c_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7c_drop        │ (None, 7, 7, 640) │          0 │ block7c_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7c_add (Add)   │ (None, 7, 7, 640) │          0 │ block7c_drop[0][… │
# │                     │                   │            │ block7b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7d_expand_conv │ (None, 7, 7,      │  2,457,600 │ block7c_add[0][0] │
# │ (Conv2D)            │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7d_expand_bn   │ (None, 7, 7,      │     15,360 │ block7d_expand_c… │
# │ (BatchNormalizatio… │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7d_expand_act… │ (None, 7, 7,      │          0 │ block7d_expand_b… │
# │ (Activation)        │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7d_dwconv      │ (None, 7, 7,      │     34,560 │ block7d_expand_a… │
# │ (DepthwiseConv2D)   │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7d_bn          │ (None, 7, 7,      │     15,360 │ block7d_dwconv[0… │
# │ (BatchNormalizatio… │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7d_activation  │ (None, 7, 7,      │          0 │ block7d_bn[0][0]  │
# │ (Activation)        │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7d_se_squeeze  │ (None, 3840)      │          0 │ block7d_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7d_se_reshape  │ (None, 1, 1,      │          0 │ block7d_se_squee… │
# │ (Reshape)           │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7d_se_reduce   │ (None, 1, 1, 160) │    614,560 │ block7d_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7d_se_expand   │ (None, 1, 1,      │    618,240 │ block7d_se_reduc… │
# │ (Conv2D)            │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7d_se_excite   │ (None, 7, 7,      │          0 │ block7d_activati… │
# │ (Multiply)          │ 3840)             │            │ block7d_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7d_project_co… │ (None, 7, 7, 640) │  2,457,600 │ block7d_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7d_project_bn  │ (None, 7, 7, 640) │      2,560 │ block7d_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7d_drop        │ (None, 7, 7, 640) │          0 │ block7d_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7d_add (Add)   │ (None, 7, 7, 640) │          0 │ block7d_drop[0][… │
# │                     │                   │            │ block7c_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_conv (Conv2D)   │ (None, 7, 7,      │  1,638,400 │ block7d_add[0][0] │
# │                     │ 2560)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_bn              │ (None, 7, 7,      │     10,240 │ top_conv[0][0]    │
# │ (BatchNormalizatio… │ 2560)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_activation      │ (None, 7, 7,      │          0 │ top_bn[0][0]      │
# │ (Activation)        │ 2560)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2560)      │          0 │ top_activation[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │  1,311,232 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 512)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 256)       │    131,328 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 256)       │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 8)         │      2,056 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 65,542,303 (250.02 MB)
#  Trainable params: 1,444,616 (5.51 MB)
#  Non-trainable params: 64,097,687 (244.51 MB)

# %% [markdown]
# #### Define callbacks

# %%
# Define callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=100, restore_best_weights=True)
checkpoint = ModelCheckpoint('/content/drive/MyDrive/ARWAN_MAKHIJA_IRIS/FULL_2_E_emotion_model_best.h5',
                            monitor='val_accuracy', save_best_only=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

# %% [markdown]
# #### Train the model

# %%
# Train the model
history = model.fit(
    train_generator,
    epochs=25,
    validation_data=val_generator,
    callbacks=[early_stopping, checkpoint, lr_scheduler]
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.1137 - loss: 2.1663
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2334s 10s/step - accuracy: 0.1138 - loss: 2.1661 - val_accuracy: 0.1260 - val_loss: 2.0803 - learning_rate: 0.0010
# Epoch 2/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 497s 2s/step - accuracy: 0.1340 - loss: 2.0851 - val_accuracy: 0.1236 - val_loss: 2.0795 - learning_rate: 0.0010
# Epoch 3/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 486s 2s/step - accuracy: 0.1217 - loss: 2.0799 - val_accuracy: 0.1236 - val_loss: 2.0795 - learning_rate: 0.0010
# Epoch 4/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 491s 2s/step - accuracy: 0.1269 - loss: 2.0805 - val_accuracy: 0.1254 - val_loss: 2.0818 - learning_rate: 0.0010
# Epoch 5/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 486s 2s/step - accuracy: 0.1309 - loss: 2.0797 - val_accuracy: 0.1260 - val_loss: 2.0795 - learning_rate: 0.0010
# Epoch 6/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 491s 2s/step - accuracy: 0.1318 - loss: 2.0796 - val_accuracy: 0.1260 - val_loss: 2.0795 - learning_rate: 0.0010
# Epoch 7/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 490s 2s/step - accuracy: 0.1189 - loss: 2.0804 - val_accuracy: 0.1260 - val_loss: 2.0795 - learning_rate: 0.0010
# Epoch 8/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 484s 2s/step - accuracy: 0.1218 - loss: 2.0796 - val_accuracy: 0.1248 - val_loss: 2.0794 - learning_rate: 5.0000e-04
# Epoch 9/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 487s 2s/step - accuracy: 0.1292 - loss: 2.0803 - val_accuracy: 0.1248 - val_loss: 2.0795 - learning_rate: 5.0000e-04
# Epoch 10/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 491s 2s/step - accuracy: 0.1269 - loss: 2.0796 - val_accuracy: 0.1248 - val_loss: 2.0795 - learning_rate: 5.0000e-04
# Epoch 11/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 491s 2s/step - accuracy: 0.1277 - loss: 2.0795 - val_accuracy: 0.1254 - val_loss: 2.0794 - learning_rate: 5.0000e-04
# Epoch 12/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 487s 2s/step - accuracy: 0.1330 - loss: 2.0795 - val_accuracy: 0.1248 - val_loss: 2.0794 - learning_rate: 5.0000e-04
# Epoch 13/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 481s 2s/step - accuracy: 0.1236 - loss: 2.0795 - val_accuracy: 0.1248 - val_loss: 2.0795 - learning_rate: 2.5000e-04
# Epoch 14/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 492s 2s/step - accuracy: 0.1269 - loss: 2.0794 - val_accuracy: 0.1248 - val_loss: 2.0795 - learning_rate: 2.5000e-04
# Epoch 15/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 489s 2s/step - accuracy: 0.1279 - loss: 2.0795 - val_accuracy: 0.1248 - val_loss: 2.0795 - learning_rate: 2.5000e-04
# Epoch 16/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 490s 2s/step - accuracy: 0.1280 - loss: 2.0799 - val_accuracy: 0.1248 - val_loss: 2.0795 - learning_rate: 2.5000e-04
# Epoch 17/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 488s 2s/step - accuracy: 0.1211 - loss: 2.0796 - val_accuracy: 0.1248 - val_loss: 2.0794 - learning_rate: 2.5000e-04
# Epoch 18/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 486s 2s/step - accuracy: 0.1202 - loss: 2.0795 - val_accuracy: 0.1248 - val_loss: 2.0795 - learning_rate: 1.2500e-04
# Epoch 19/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 485s 2s/step - accuracy: 0.1300 - loss: 2.0795 - val_accuracy: 0.1248 - val_loss: 2.0795 - learning_rate: 1.2500e-04
# Epoch 20/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 491s 2s/step - accuracy: 0.1227 - loss: 2.0796 - val_accuracy: 0.1248 - val_loss: 2.0795 - learning_rate: 1.2500e-04
# Epoch 21/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 494s 2s/step - accuracy: 0.1292 - loss: 2.0800 - val_accuracy: 0.1248 - val_loss: 2.0794 - learning_rate: 1.2500e-04
# Epoch 22/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 499s 2s/step - accuracy: 0.1252 - loss: 2.0795 - val_accuracy: 0.1248 - val_loss: 2.0795 - learning_rate: 1.2500e-04
# Epoch 23/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 501s 2s/step - accuracy: 0.1277 - loss: 2.0795 - val_accuracy: 0.1248 - val_loss: 2.0795 - learning_rate: 6.2500e-05
# Epoch 24/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 506s 2s/step - accuracy: 0.1211 - loss: 2.0794 - val_accuracy: 0.1248 - val_loss: 2.0795 - learning_rate: 6.2500e-05
# Epoch 25/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 499s 2s/step - accuracy: 0.1327 - loss: 2.0794 - val_accuracy: 0.1248 - val_loss: 2.0794 - learning_rate: 6.2500e-05

# %% [markdown]
# #### Evaluate on test set

# %%
# Evaluate on test set
test_loss, test_accuracy = model.evaluate(test_generator)
print(f"\n✅ Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 483s 9s/step - accuracy: 0.0500 - loss: 2.0803
#
# ✅ Test Accuracy: 12.42%

# %% [markdown]
# #### Plot training and validation metrics

# %%
# Plot training and validation metrics
def plot_training_metrics(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(len(acc))

    plt.figure(figsize=(14, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy', marker='o')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy', marker='x')
    plt.title('📈 Training & Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss', marker='o', linestyle='--')
    plt.plot(epochs_range, val_loss, label='Validation Loss', marker='x', linestyle='--')
    plt.title('📉 Training & Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

plot_training_metrics(history)
# Out:
# <ipython-input-16-d8556b0d2d7f>:28: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-16-d8556b0d2d7f>:28: UserWarning: Glyph 128201 (\N{CHART WITH DOWNWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128201 (\N{CHART WITH DOWNWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# #### Confusion matrix and classification report

# %%
# Confusion matrix and classification report
def plot_confusion_matrix(model, test_generator):
    class_names = list(test_generator.class_indices.keys())
    y_pred_probs = model.predict(test_generator)
    y_pred = np.argmax(y_pred_probs, axis=1)
    y_true = test_generator.classes

    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.title('Confusion Matrix 📊')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.xticks(rotation=45, ha='right')
    plt.show()

    print("Classification Report:")
    print(classification_report(y_true, y_pred, target_names=class_names))

plot_confusion_matrix(model, test_generator)
# Out:
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 98s 2s/step
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# Classification Report:
#                  precision    recall  f1-score   support
#
#    Class1_Happy       0.00      0.00      0.00       212
#   Class1_Lonely       0.00      0.00      0.00       210
#     Class1_Love       0.00      0.00      0.00       211
#   Class1_Normal       0.00      0.00      0.00       209
# Class1_Restless       0.00      0.00      0.00       209
#      Class1_Sad       0.12      1.00      0.22       209
#   Class1_Stress       0.00      0.00      0.00       211
#    Class1_Tired       0.00      0.00      0.00       212
#
#        accuracy                           0.12      1683
#       macro avg       0.02      0.12      0.03      1683
#    weighted avg       0.02      0.12      0.03      1683
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# #### Grad-CAM for interpretability

# %%
# Grad-CAM for interpretability
def get_gradcam_heatmap(model, img_array, last_conv_layer_name):
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )

    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        predicted_class = tf.argmax(predictions[0])
        class_output = predictions[:, predicted_class]

    grads = tape.gradient(class_output, conv_outputs)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    conv_outputs = conv_outputs[0]
    heatmap = tf.reduce_mean(tf.multiply(conv_outputs, pooled_grads), axis=-1)
    heatmap = np.maximum(heatmap, 0) / np.max(heatmap)
    return heatmap

def display_gradcam(img_path, model, last_conv_layer_name):
    img = image.load_img(img_path, target_size=(IMG_HEIGHT, IMG_WIDTH))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0

    heatmap = get_gradcam_heatmap(model, img_array, last_conv_layer_name)
    heatmap = cv2.resize(heatmap, (IMG_WIDTH, IMG_HEIGHT))

    img = cv2.imread(img_path)
    img = cv2.resize(img, (IMG_WIDTH, IMG_HEIGHT))
    heatmap = np.uint8(255 * heatmap)
    heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)

    superimposed_img = heatmap * 0.4 + img
    superimposed_img = np.clip(superimposed_img, 0, 255).astype(np.uint8)

    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.title('Original Image')
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(cv2.cvtColor(superimposed_img, cv2.COLOR_BGR2RGB))
    plt.title('Grad-CAM Heatmap')
    plt.axis('off')

    plt.show()

# %% [markdown]
# #### Grad-CAM visualization

# %%
# Grad-CAM visualization
img_path = '/content/drive/MyDrive/ARWAN_MAKHIJA_IRIS/Cocker_Spaniel_Emotions_Dataset/Cocker_Spaniel_Emotions_Splitted/test/Class1_Happy/Class0_00F70KTJDXLD.jpg'  # Update with actual path
display_gradcam(img_path, model, 'top_conv')  # Last conv layer in EfficientNetB7
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: [['keras_tensor']]
# Received: inputs=Tensor(shape=(1, 224, 224, 3))
#   warnings.warn(msg)
# <ipython-input-18-360fd2867dd3>:17: RuntimeWarning: invalid value encountered in divide
#   heatmap = np.maximum(heatmap, 0) / np.max(heatmap)
# <ipython-input-18-360fd2867dd3>:30: RuntimeWarning: invalid value encountered in cast
#   heatmap = np.uint8(255 * heatmap)

# %% [markdown]
# #### Save the EfficientNetB7 model

# %%
# Save the EfficientNetB7 model
model.save('/content/drive/MyDrive/ARWAN_MAKHIJA_IRIS/model/EfficientNetB7_Model-FULL-2_emotion_model.h5')
print("✅ Model saved successfully as 'emotion_detection_EfficientNetB7_FULL.h5'")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Model saved successfully as 'emotion_detection_EfficientNetB7_FULL.h5'

# %% [markdown]
# #### Test prediction
# #### Test prediction on a single image

# %%
# Test prediction on a single image
def predict_single_image(img_path, model):
    img = image.load_img(img_path, target_size=(IMG_HEIGHT, IMG_WIDTH))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0

    prediction = model.predict(img_array)
    predicted_class = emotion_classes[np.argmax(prediction)]

    plt.imshow(img)
    plt.title(f"Predicted Emotion: {predicted_class}")
    plt.axis('off')
    plt.show()

predict_single_image(img_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step

# %% [markdown]
# ----
# ---
# ---

# %% [markdown]
# # 1) Count total images

# %%
# Count total images
total_images = len(list(dataset_dir.glob('*/*.jpg'))) + len(list(dataset_dir.glob('*/*.png')))
print(f"Total images in dataset: {total_images}")
# Out:
# Total images in dataset: 6012

# %% [markdown]
# # 1) Define emotion classes and labels

# %%
# Define emotion classes and labels
#emotion_classes = ["Sad", "Happy", "Stress", "Restless", "Normal", "Love", "Unhappy", "Tired"]
emotion_classes = ["Class1_Sad", "Class1_Happy", "Class1_Stress", "Class1_Restless", "Class1_Love", "Class1_Lonely", "Class1_Tired", "Class1_Normal"]
class_labels = {cls: idx for idx, cls in enumerate(emotion_classes)}
image_counts = {}
image_paths = {}

# %% [markdown]
# # 1) Count images per class

# %%
# Count images per class
for cls in emotion_classes:
    count = len(list(dataset_dir.glob(f'{cls}/*')))
    paths = list(dataset_dir.glob(f'{cls}/*'))
    image_counts[cls] = count
    image_paths[cls] = paths
    print(f"{cls}: {count} images")

# %% [markdown]
# # 1) Visualize sample images

# %%
# Visualize sample images
for cls, paths in image_paths.items():
    if paths:
        print(f"\nSample {cls} Image:")
        PIL.Image.open(str(paths[min(10, len(paths)-1)])).show()

# %% [markdown]
# # 1) Plot class distribution

# %%
# Plot class distribution
plt.figure(figsize=(10, 6))
plt.bar(image_counts.keys(), image_counts.values(), color='skyblue')
plt.xlabel('Emotion Class')
plt.ylabel('Number of Images')
plt.title('Distribution of Cocker Spaniel Emotion Images')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 1) Split dataset into train, validation, and test sets

# %%
# Split dataset into train, validation, and test sets
def split_dataset(dataset_dir, output_dir, train_ratio=0.7, val_ratio=0.15, test_ratio=0.15):
    for split in ['train', 'val', 'test']:
        os.makedirs(os.path.join(output_dir, split), exist_ok=True)

    for cls in emotion_classes:
        class_path = os.path.join(dataset_dir, cls)
        images = os.listdir(class_path)
        random.shuffle(images)

        total_images = len(images)
        train_end = int(train_ratio * total_images)
        val_end = train_end + int(val_ratio * total_images)

        train_images = images[:train_end]
        val_images = images[train_end:val_end]
        test_images = images[val_end:]

        def copy_images(image_list, split):
            split_class_dir = os.path.join(output_dir, split, cls)
            os.makedirs(split_class_dir, exist_ok=True)
            for img in image_list:
                src = os.path.join(class_path, img)
                dst = os.path.join(split_class_dir, img)
                shutil.copy(src, dst)

        copy_images(train_images, 'train')
        copy_images(val_images, 'val')
        copy_images(test_images, 'test')

splitted_dataset_dir = '/content/drive/MyDrive/Cocker_Spaniel_Emotions_Splitted'
split_dataset(dataset_dir, splitted_dataset_dir)
print("✅ Dataset successfully split into training, validation, and testing sets!")

# %% [markdown]
# # 1) Verify split counts

# %%
# Verify split counts
for split in ['train', 'val', 'test']:
    print(f"\n📂 {split.upper()} SET:")
    split_path = os.path.join(splitted_dataset_dir, split)
    for cls in emotion_classes:
        class_path = os.path.join(split_path, cls)
        num_images = len(os.listdir(class_path)) if os.path.exists(class_path) else 0
        print(f"   - {cls}: {num_images} images")

# %% [markdown]
# # 1) Data augmentation and generators

# %%
# Data augmentation and generators
IMG_HEIGHT, IMG_WIDTH, BATCH_SIZE = 224, 224, 32
NUM_CLASSES = 8

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    fill_mode='nearest'
)

val_test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    f'{splitted_dataset_dir}/train',
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

val_generator = val_test_datagen.flow_from_directory(
    f'{splitted_dataset_dir}/val',
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

test_generator = val_test_datagen.flow_from_directory(
    f'{splitted_dataset_dir}/test',
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print("\nClass indices:", train_generator.class_indices)

# %% [markdown]
# # 1) Define EfficientNetB7-based model

# %%
# Define EfficientNetB7-based model
def create_EfficientNetB7_model():
    base_model = EfficientNetB7(weights='imagenet', include_top=False, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))
    base_model.trainable = False  # Freeze base model layers

    inputs = base_model.input
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.3)(x)
    outputs = Dense(NUM_CLASSES, activation='softmax')(x)

    model = Model(inputs=inputs, outputs=outputs)
    return model

model = create_EfficientNetB7_model()
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()

# %% [markdown]
# # 1) Define callbacks

# %%
# Define callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
checkpoint = ModelCheckpoint('/content/drive/MyDrive/Cocker_Spaniel_Emotions/emotion_model_best.h5',
                            monitor='val_accuracy', save_best_only=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

# %% [markdown]
# # 1) Train the model

# %%
# Train the model
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=val_generator,
    callbacks=[early_stopping, checkpoint, lr_scheduler]
)

# %% [markdown]
# # 1) Evaluate on test set

# %%
# Evaluate on test set
test_loss, test_accuracy = model.evaluate(test_generator)
print(f"\n✅ Test Accuracy: {test_accuracy * 100:.2f}%")

# %% [markdown]
# # 1) Plot training and validation metrics

# %%
# Plot training and validation metrics
def plot_training_metrics(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(len(acc))

    plt.figure(figsize=(14, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy', marker='o')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy', marker='x')
    plt.title('📈 Training & Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss', marker='o', linestyle='--')
    plt.plot(epochs_range, val_loss, label='Validation Loss', marker='x', linestyle='--')
    plt.title('📉 Training & Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

plot_training_metrics(history)

# %% [markdown]
# # 1) Confusion matrix and classification report

# %%
# Confusion matrix and classification report
def plot_confusion_matrix(model, test_generator):
    class_names = list(test_generator.class_indices.keys())
    y_pred_probs = model.predict(test_generator)
    y_pred = np.argmax(y_pred_probs, axis=1)
    y_true = test_generator.classes

    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.title('Confusion Matrix 📊')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.xticks(rotation=45, ha='right')
    plt.show()

    print("Classification Report:")
    print(classification_report(y_true, y_pred, target_names=class_names))

plot_confusion_matrix(model, test_generator)

# %% [markdown]
# # 1) Grad-CAM for interpretability

# %%
# Grad-CAM for interpretability
def get_gradcam_heatmap(model, img_array, last_conv_layer_name):
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )

    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        predicted_class = tf.argmax(predictions[0])
        class_output = predictions[:, predicted_class]

    grads = tape.gradient(class_output, conv_outputs)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    conv_outputs = conv_outputs[0]
    heatmap = tf.reduce_mean(tf.multiply(conv_outputs, pooled_grads), axis=-1)
    heatmap = np.maximum(heatmap, 0) / np.max(heatmap)
    return heatmap

def display_gradcam(img_path, model, last_conv_layer_name):
    img = image.load_img(img_path, target_size=(IMG_HEIGHT, IMG_WIDTH))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0

    heatmap = get_gradcam_heatmap(model, img_array, last_conv_layer_name)
    heatmap = cv2.resize(heatmap, (IMG_WIDTH, IMG_HEIGHT))

    img = cv2.imread(img_path)
    img = cv2.resize(img, (IMG_WIDTH, IMG_HEIGHT))
    heatmap = np.uint8(255 * heatmap)
    heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)

    superimposed_img = heatmap * 0.4 + img
    superimposed_img = np.clip(superimposed_img, 0, 255).astype(np.uint8)

    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.title('Original Image')
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(cv2.cvtColor(superimposed_img, cv2.COLOR_BGR2RGB))
    plt.title('Grad-CAM Heatmap')
    plt.axis('off')

    plt.show()

# %% [markdown]
# # 1) Grad-CAM visualization

# %%
# Grad-CAM visualization
img_path = '/content/drive/MyDrive/Cocker_Spaniel_Emotions_Splitted/val/Happy/sample_image.jpg'  # Update with actual path
display_gradcam(img_path, model, 'conv5_block3_3_conv')  # Last conv layer in EfficientNetB7

# %% [markdown]
# # 1) Save the EfficientNetB7 model

# %%
# Save the EfficientNetB7 model
model.save('/content/drive/MyDrive/Cocker_Spaniel_Emotions/emotion_detection_EfficientNetB7.h5')
print("✅ Model saved successfully as 'emotion_detection_EfficientNetB7.h5'")

# %% [markdown]
# # 1) Test prediction
# ## Test prediction on a single image

# %%
# Test prediction on a single image
def predict_single_image(img_path, model):
    img = image.load_img(img_path, target_size=(IMG_HEIGHT, IMG_WIDTH))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0

    prediction = model.predict(img_array)
    predicted_class = emotion_classes[np.argmax(prediction)]

    plt.imshow(img)
    plt.title(f"Predicted Emotion: {predicted_class}")
    plt.axis('off')
    plt.show()

predict_single_image(img_path, model)

# %% [markdown]
# ---
# ---
# ---
# ---
